# %%
import pyshark
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
import nest_asyncio
nest_asyncio.apply()

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
ATTACK_START = 20
ATTACK_END = 120
PCAP_FILE = "flood.pcap"

# %%
def parse_pcap(file_path):
    connections = defaultdict(lambda: {'start_time': None, 'fin_ack_time': None, 'end_time': None})
    cap = pyshark.FileCapture(file_path, display_filter="tcp.port==8080")
    
    for pkt in cap:
        try:
            src_ip = pkt.ip.src
            dst_ip = pkt.ip.dst
            src_port = int(pkt.tcp.srcport)
            dst_port = int(pkt.tcp.dstport)
            timestamp = float(pkt.sniff_timestamp)
            flags = int(pkt.tcp.flags, 16)
            
            conn_tuple = (src_ip, dst_ip, src_port, dst_port)
            reverse_tuple = (dst_ip, src_ip, dst_port, src_port)
            
            # Initialize start_time with the first SYN
            if flags == 0x0002:  # SYN only
                if connections[conn_tuple]['start_time'] is None:
                    connections[conn_tuple]['start_time'] = timestamp
            
            # Record FIN-ACK (potential end from either direction)
            elif flags == 0x0011:  # FIN-ACK
                if connections[conn_tuple]['start_time'] is not None and connections[conn_tuple]['fin_ack_time'] is None:
                    connections[conn_tuple]['fin_ack_time'] = timestamp
                elif connections[reverse_tuple]['start_time'] is not None and connections[reverse_tuple]['fin_ack_time'] is None:
                    connections[reverse_tuple]['fin_ack_time'] = timestamp
            
            # Record final ACK (after FIN-ACK) from either direction
            elif flags == 0x0010:  # ACK
                if (connections[conn_tuple]['fin_ack_time'] is not None and 
                    connections[conn_tuple]['end_time'] is None):
                    connections[conn_tuple]['end_time'] = timestamp
                elif (connections[reverse_tuple]['fin_ack_time'] is not None and 
                      connections[reverse_tuple]['end_time'] is None):
                    connections[reverse_tuple]['end_time'] = timestamp
            
            # Record RST (abrupt end) from either direction
            elif flags & 0x0004:  # RST flag
                if (connections[conn_tuple]['start_time'] is not None and 
                    connections[conn_tuple]['end_time'] is None):
                    connections[conn_tuple]['end_time'] = timestamp
                elif (connections[reverse_tuple]['start_time'] is not None and 
                      connections[reverse_tuple]['end_time'] is None):
                    connections[reverse_tuple]['end_time'] = timestamp
        
        except AttributeError:
            continue  # Skip non-TCP packets
    
    cap.close()
    return connections

def calculate_durations_and_stats(connections):
    durations = []
    start_times = []
    stats = {'non_attack': {'durations': [], 'count': 0, 'completed': 0},
             'attack': {'durations': [], 'count': 0, 'completed': 0}}
    first_timestamp = min(conn['start_time'] for conn in connections.values() if conn['start_time'] is not None)
    
    for conn, details in connections.items():
        if details['start_time'] is not None:
            start_time = details['start_time'] - first_timestamp
            if details['end_time'] is not None:
                duration = details['end_time'] - details['start_time']
            else:
                duration = 100.0  # Default for incomplete connections
            
            durations.append(duration)
            start_times.append(start_time)
            
            # Categorize by attack phase
            if ATTACK_START <= start_time <= ATTACK_END + 3:
                stats['attack']['durations'].append(duration)
                stats['attack']['count'] += 1
                if duration < 100.0:
                    stats['attack']['completed'] += 1
            else:
                stats['non_attack']['durations'].append(duration)
                stats['non_attack']['count'] += 1
                if duration < 100.0:
                    stats['non_attack']['completed'] += 1
    
    return start_times, durations, stats

def print_statistics(stats):
    print("\nConnection Statistics:")
    for phase in ['non_attack', 'attack']:
        durations = stats[phase]['durations']
        if durations:
            avg_duration = np.mean(durations)
            median_duration = np.median(durations)
            max_duration = np.max(durations)
            min_duration = np.min(durations)
            completed_pct = (stats[phase]['completed'] / stats[phase]['count'] * 100) if stats[phase]['count'] > 0 else 0
            
            print(f"\n{phase.capitalize()} Phase (t=0-{ATTACK_START}s and t={ATTACK_END}s-140s if non_attack, t={ATTACK_START}s-{ATTACK_END}s if attack):")
            print(f"  Total Connections: {stats[phase]['count']}")
            print(f"  Completed Connections: {stats[phase]['completed']} ({completed_pct:.6f}%)")
            print(f"  Average Duration: {avg_duration:.6f} seconds")
            print(f"  Median Duration: {median_duration:.6f} seconds")
            print(f"  Max Duration: {max_duration:.6f} seconds")
            print(f"  Min Duration: {min_duration:.6f} seconds")
            if phase == 'attack' and max_duration > 2.0:  # Highlight long durations
                print(f"  Note: {stats[phase]['completed']} legitimate connections completed with unusually long durations (e.g., >2s)")

def plot_durations(start_times, durations):
    plt.figure(figsize=(12, 6))
    plt.scatter(start_times, durations, alpha=0.5, label="TCP Connections")
    
    # Mark attack start and end
    plt.axvline(x=ATTACK_START, color='r', linestyle='--', label=f"Attack Start ({ATTACK_START}s)")
    plt.axvline(x=ATTACK_END, color='g', linestyle='--', label=f"Attack End ({ATTACK_END}s)")
    
    plt.xlabel("Connection Start Time (seconds)")
    plt.ylabel("Connection Duration (seconds)")
    plt.title("TCP Connection Durations vs. Start Time")
    plt.legend()
    plt.grid(True)
    # plt.yscale('symlog')
    plt.savefig("connection_durations.png", dpi=300)
    plt.show()

# %%
print("Processing PCAP file...")
connections = parse_pcap(PCAP_FILE)
start_times, durations, stats = calculate_durations_and_stats(connections)
print(f"Processed {len(start_times)} TCP connections")
# Out:
# Processing PCAP file...
# Processed 92847 TCP connections

# %%
print_statistics(stats)
plot_durations(start_times, durations)
# Out:
# Connection Statistics:
#
# Non_attack Phase (t=0-20s and t=120s-140s if non_attack, t=20s-120s if attack):
#   Total Connections: 23
#   Completed Connections: 23 (100.000000%)
#   Average Duration: 0.006899 seconds
#   Median Duration: 0.006868 seconds
#   Max Duration: 0.012075 seconds
#   Min Duration: 0.002884 seconds
#
# Attack Phase (t=0-20s and t=120s-140s if non_attack, t=20s-120s if attack):
#   Total Connections: 92824
#   Completed Connections: 2 (0.002155%)
#   Average Duration: 99.998968 seconds
#   Median Duration: 100.000000 seconds
#   Max Duration: 100.000000 seconds
#   Min Duration: 36.047526 seconds
#   Note: 2 legitimate connections completed with unusually long durations (e.g., >2s)

# %%
connections
# Out:
# defaultdict(<function __main__.parse_pcap.<locals>.<lambda>()>,
#             {('192.168.64.2',
#               '192.168.64.3',
#               46428,
#               8080): {'start_time': 1741546054.376098, 'fin_ack_time': 1741546054.377894, 'end_time': 1741546054.379221},
#              ('192.168.64.3',
#               '192.168.64.2',
#               8080,
#               46428): {'start_time': None, 'fin_ack_time': None, 'end_time': None},
#              ('192.168.64.2',
#               '192.168.64.3',
#               46438,
#               8080): {'start_time': 1741546055.880526, 'fin_ack_time': 1741546055.886047, 'end_time': 1741546055.887394},
#              ('192.168.64.3',
#               '192.168.64.2',
#               8080,
#               46438): {'start_time': None, 'fin_ack_time': None, 'end_time': None},
#              ('192.168.64.2',
#               '192.168.64.3',
#               46454,
#               8080): {'start_time': 1741546057.389615, 'fin_ack_time': 1741546057.396359, 'end_time': 1741546057.397333},
#              ('192.168.64.3',
#               '192.168.64.2',
#               8080,
#               46454): {'start_time': None, 'fin_ack_time': None, 'end_time': None},
#              ('192.168.64.2',
#               '192.168.64.3',
#               46460,
#               8080): {'start_time': 1741546058.895265, 'fin_ack_time': 1741546058.901414, 'end_time': 1741546058.902433},
#              ('192.168.64.3',
#               '192.168.64.2',
#               8080,
#               46460): {'start_time': None, 'fin_ack_time': None, 'end_time': None},
#              ('192.168.64.2',
#               '192.168.64.3',
#               46466,
#               8080): {'start_time': 1741546060.406212, 'fin_ack_time': 1741546060.412237, 'end_time': 1741546060.413396},
#              ('192.168.64.3',
#               '192.168.64.2',
#               8080,
#               46466): {'start_time': None, 'fin_ack_time': None, 'end_time': None},
#              ('192.168.64.2',
#               '192.168.64.3',
#               46468,
#               8080): {'start_time': 1741546061.912346, 'fin_ack_time': 1741546061.914371, 'end_time': 1741546061.91523},
#              ('192.168.64.3',
#               '192.168.64.2',
#               8080,
#               46468): {'start_time': None, 'fin_ack_time': None, 'end_time': None},
#              ('192.168.64.2',
#               '192.168.64.3',
#               42120,
#               8080): {'start_time': 1741546063.419721, 'fin_ack_time': 1741546063.425256, 'end_time': 1741546063.426388},
#              ('192.168.64.3',
#               '192.168.64.2',
#               8080,
#               42120): {'start_time': None, 'fin_ack_time': None, 'end_time': None},
#              ('192.168.64.2',
#               '192.168.64.3',
#               42126,
#               8080): {'start_time': 1741546064.929151, 'fin_ack_time': 1741546064.933302, 'end_time': 1741546064.934404},
#              ('192.168.64.3',
#               '192.168.64.2',
#               8080,
#               42126): {'start_time': None, 'fin_ack_time': None, 'end_time': None},
#              ('192.168.64.2',
#               '192.168.64.3',
#               42132,
#               8080): {'start_time': 1741546066.431975, 'fin_ack_time': 1741546066.436634, 'end_time': 1741546066.437285},
#              ('192.168.64.3',
#               '192.168.64.2',
#               8080,
#               42132): {'start_time': None, 'fin_ack_time': None, 'end_time': None},
#              ('192.168.64.2',
#               '192.168.64.3',
#               42142,
#               8080): {'start_time': 1741546067.939628, 'fin_ack_time': 1741546067.945062, 'end_time': 1741546067.946416},
#              ('192.168.64.3',
#               '192.168.64.2',
#               8080,
#               42142): {'start_time': None, 'fin_ack_time': None, 'end_time': None},
#              ('192.168.64.2',
#               '192.168.64.3',
#               42156,
#               8080): {'start_time': 1741546069.444903, 'fin_ack_time': 1741546069.44907, 'end_time': 1741546069.45042},
#              ('192.168.64.3',
#               '192.168.64.2',
#               8080,
#               42156): {'start_time': None, 'fin_ack_time': None, 'end_time': None},
#              ('192.168.64.2',
#               '192.168.64.3',
#               42162,
#               8080): {'start_time': 1741546070.950301, 'fin_ack_time': 1741546070.955779, 'end_time': 1741546070.957437},
#              ('192.168.64.3',
#               '192.168.64.2',
#               8080,
#               42162): {'start_time': None, 'fin_ack_time': None, 'end_time': None},
#              ('192.168.64.2',
#               '192.168.64.3',
#               38810,
#               8080): {'start_time': 1741546072.458161, 'fin_ack_time': 1741546072.463143, 'end_time': 1741546072.464455},
#              ('192.168.64.3',
#               '192.168.64.2',
#               8080,
#               38810): {'start_time': None, 'fin_ack_time': None, 'end_time': None},
#              ('192.168.64.2',
#               '192.168.64.3',
#               38824,
#               8080): {'start_time': 1741546073.965476, 'fin_ack_time': 1741546073.971189, 'end_time': 1741546073.972421},
#              ('192.168.64.3',
#               '192.168.64.2',
#               8080,
#               38824): {'start_time': None, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.226',
#               '192.168.64.3',
#               26438,
#               8080): {'start_time': 1741546074.819572, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.202',
#               '192.168.64.3',
#               33290,
#               8080): {'start_time': 1741546074.820658, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.39',
#               '192.168.64.3',
#               16853,
#               8080): {'start_time': 1741546074.82177, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.151',
#               '192.168.64.3',
#               34992,
#               8080): {'start_time': 1741546074.822822, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.148',
#               '192.168.64.3',
#               61473,
#               8080): {'start_time': 1741546074.823934, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.140',
#               '192.168.64.3',
#               18883,
#               8080): {'start_time': 1741546074.825102, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.231',
#               '192.168.64.3',
#               55843,
#               8080): {'start_time': 1741546074.826079, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.79',
#               '192.168.64.3',
#               61476,
#               8080): {'start_time': 1741546074.827159, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.246',
#               '192.168.64.3',
#               26058,
#               8080): {'start_time': 1741546074.828223, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.207',
#               '192.168.64.3',
#               4296,
#               8080): {'start_time': 1741546074.829307, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.240',
#               '192.168.64.3',
#               20983,
#               8080): {'start_time': 1741546074.830383, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.234',
#               '192.168.64.3',
#               56494,
#               8080): {'start_time': 1741546074.831488, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.150',
#               '192.168.64.3',
#               39031,
#               8080): {'start_time': 1741546074.832538, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.159',
#               '192.168.64.3',
#               2717,
#               8080): {'start_time': 1741546074.833643, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.215',
#               '192.168.64.3',
#               34444,
#               8080): {'start_time': 1741546074.834688, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.65',
#               '192.168.64.3',
#               58961,
#               8080): {'start_time': 1741546074.836009, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.44',
#               '192.168.64.3',
#               38291,
#               8080): {'start_time': 1741546074.837019, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.173',
#               '192.168.64.3',
#               11168,
#               8080): {'start_time': 1741546074.838131, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.175',
#               '192.168.64.3',
#               59072,
#               8080): {'start_time': 1741546074.839258, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.92',
#               '192.168.64.3',
#               58560,
#               8080): {'start_time': 1741546074.840365, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.237',
#               '192.168.64.3',
#               25830,
#               8080): {'start_time': 1741546074.841446, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.155',
#               '192.168.64.3',
#               46224,
#               8080): {'start_time': 1741546074.842523, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.160',
#               '192.168.64.3',
#               38780,
#               8080): {'start_time': 1741546074.843633, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.216',
#               '192.168.64.3',
#               52035,
#               8080): {'start_time': 1741546074.844704, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.171',
#               '192.168.64.3',
#               65478,
#               8080): {'start_time': 1741546074.845729, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.103',
#               '192.168.64.3',
#               24118,
#               8080): {'start_time': 1741546074.84686, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.154',
#               '192.168.64.3',
#               49882,
#               8080): {'start_time': 1741546074.847912, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.91',
#               '192.168.64.3',
#               43723,
#               8080): {'start_time': 1741546074.849069, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.120',
#               '192.168.64.3',
#               56892,
#               8080): {'start_time': 1741546074.850069, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.231',
#               '192.168.64.3',
#               64823,
#               8080): {'start_time': 1741546074.851169, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.142',
#               '192.168.64.3',
#               32935,
#               8080): {'start_time': 1741546074.852279, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.171',
#               '192.168.64.3',
#               25461,
#               8080): {'start_time': 1741546074.853308, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.150',
#               '192.168.64.3',
#               22529,
#               8080): {'start_time': 1741546074.854413, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.26',
#               '192.168.64.3',
#               61367,
#               8080): {'start_time': 1741546074.85545, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.211',
#               '192.168.64.3',
#               33096,
#               8080): {'start_time': 1741546074.856543, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.194',
#               '192.168.64.3',
#               16178,
#               8080): {'start_time': 1741546074.857633, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.252',
#               '192.168.64.3',
#               20049,
#               8080): {'start_time': 1741546074.858687, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.44',
#               '192.168.64.3',
#               7620,
#               8080): {'start_time': 1741546074.859771, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.134',
#               '192.168.64.3',
#               22369,
#               8080): {'start_time': 1741546074.860844, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.81',
#               '192.168.64.3',
#               35357,
#               8080): {'start_time': 1741546074.861889, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.13',
#               '192.168.64.3',
#               7035,
#               8080): {'start_time': 1741546074.862971, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.207',
#               '192.168.64.3',
#               20811,
#               8080): {'start_time': 1741546074.864059, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.152',
#               '192.168.64.3',
#               23161,
#               8080): {'start_time': 1741546074.865139, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.104',
#               '192.168.64.3',
#               45485,
#               8080): {'start_time': 1741546074.866202, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.54',
#               '192.168.64.3',
#               64042,
#               8080): {'start_time': 1741546074.867212, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.146',
#               '192.168.64.3',
#               47926,
#               8080): {'start_time': 1741546074.868332, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.79',
#               '192.168.64.3',
#               8151,
#               8080): {'start_time': 1741546074.869405, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.217',
#               '192.168.64.3',
#               48315,
#               8080): {'start_time': 1741546074.870478, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.42',
#               '192.168.64.3',
#               18336,
#               8080): {'start_time': 1741546074.871562, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.152',
#               '192.168.64.3',
#               20781,
#               8080): {'start_time': 1741546074.872609, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.93',
#               '192.168.64.3',
#               56403,
#               8080): {'start_time': 1741546074.87368, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.200',
#               '192.168.64.3',
#               37722,
#               8080): {'start_time': 1741546074.874758, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.251',
#               '192.168.64.3',
#               13674,
#               8080): {'start_time': 1741546074.875812, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.156',
#               '192.168.64.3',
#               5971,
#               8080): {'start_time': 1741546074.876926, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.121',
#               '192.168.64.3',
#               37023,
#               8080): {'start_time': 1741546074.878007, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.175',
#               '192.168.64.3',
#               21264,
#               8080): {'start_time': 1741546074.879083, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.141',
#               '192.168.64.3',
#               37448,
#               8080): {'start_time': 1741546074.880124, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.188',
#               '192.168.64.3',
#               43787,
#               8080): {'start_time': 1741546074.881228, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.227',
#               '192.168.64.3',
#               33603,
#               8080): {'start_time': 1741546074.8823, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.21',
#               '192.168.64.3',
#               13039,
#               8080): {'start_time': 1741546074.883381, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.18',
#               '192.168.64.3',
#               30563,
#               8080): {'start_time': 1741546074.884464, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.233',
#               '192.168.64.3',
#               23287,
#               8080): {'start_time': 1741546074.885534, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.100',
#               '192.168.64.3',
#               37016,
#               8080): {'start_time': 1741546074.886608, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.219',
#               '192.168.64.3',
#               52685,
#               8080): {'start_time': 1741546074.887677, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.48',
#               '192.168.64.3',
#               34152,
#               8080): {'start_time': 1741546074.888736, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.202',
#               '192.168.64.3',
#               64497,
#               8080): {'start_time': 1741546074.889852, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.253',
#               '192.168.64.3',
#               1498,
#               8080): {'start_time': 1741546074.890904, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.194',
#               '192.168.64.3',
#               52509,
#               8080): {'start_time': 1741546074.891972, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.28',
#               '192.168.64.3',
#               29506,
#               8080): {'start_time': 1741546074.893079, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.118',
#               '192.168.64.3',
#               3015,
#               8080): {'start_time': 1741546074.894167, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.197',
#               '192.168.64.3',
#               22244,
#               8080): {'start_time': 1741546074.895278, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.56',
#               '192.168.64.3',
#               61173,
#               8080): {'start_time': 1741546074.896324, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.177',
#               '192.168.64.3',
#               13107,
#               8080): {'start_time': 1741546074.897402, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.66',
#               '192.168.64.3',
#               56986,
#               8080): {'start_time': 1741546074.898454, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.176',
#               '192.168.64.3',
#               24587,
#               8080): {'start_time': 1741546074.899532, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.196',
#               '192.168.64.3',
#               22785,
#               8080): {'start_time': 1741546074.900614, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.241',
#               '192.168.64.3',
#               27457,
#               8080): {'start_time': 1741546074.9017, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.78',
#               '192.168.64.3',
#               12784,
#               8080): {'start_time': 1741546074.902752, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.105',
#               '192.168.64.3',
#               58913,
#               8080): {'start_time': 1741546074.9038, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.255',
#               '192.168.64.3',
#               20200,
#               8080): {'start_time': 1741546074.904906, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.48',
#               '192.168.64.3',
#               36734,
#               8080): {'start_time': 1741546074.90598, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.12',
#               '192.168.64.3',
#               64074,
#               8080): {'start_time': 1741546074.907056, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.215',
#               '192.168.64.3',
#               64561,
#               8080): {'start_time': 1741546074.908121, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.107',
#               '192.168.64.3',
#               51852,
#               8080): {'start_time': 1741546074.909222, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.126',
#               '192.168.64.3',
#               65308,
#               8080): {'start_time': 1741546074.910326, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.28',
#               '192.168.64.3',
#               37444,
#               8080): {'start_time': 1741546074.911348, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.233',
#               '192.168.64.3',
#               19868,
#               8080): {'start_time': 1741546074.912471, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.64',
#               '192.168.64.3',
#               50204,
#               8080): {'start_time': 1741546074.913522, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.63',
#               '192.168.64.3',
#               34098,
#               8080): {'start_time': 1741546074.914597, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.68',
#               '192.168.64.3',
#               25612,
#               8080): {'start_time': 1741546074.915712, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.192',
#               '192.168.64.3',
#               26897,
#               8080): {'start_time': 1741546074.916743, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.112',
#               '192.168.64.3',
#               65041,
#               8080): {'start_time': 1741546074.917822, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.240',
#               '192.168.64.3',
#               43744,
#               8080): {'start_time': 1741546074.918903, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.176',
#               '192.168.64.3',
#               12198,
#               8080): {'start_time': 1741546074.920011, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.67',
#               '192.168.64.3',
#               40490,
#               8080): {'start_time': 1741546074.921044, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.180',
#               '192.168.64.3',
#               1269,
#               8080): {'start_time': 1741546074.922116, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.246',
#               '192.168.64.3',
#               14548,
#               8080): {'start_time': 1741546074.9232, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.214',
#               '192.168.64.3',
#               42877,
#               8080): {'start_time': 1741546074.924242, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.249',
#               '192.168.64.3',
#               19161,
#               8080): {'start_time': 1741546074.925321, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.87',
#               '192.168.64.3',
#               10355,
#               8080): {'start_time': 1741546074.92641, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.46',
#               '192.168.64.3',
#               35229,
#               8080): {'start_time': 1741546074.927442, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.225',
#               '192.168.64.3',
#               5129,
#               8080): {'start_time': 1741546074.928574, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.187',
#               '192.168.64.3',
#               18201,
#               8080): {'start_time': 1741546074.929622, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.165',
#               '192.168.64.3',
#               31741,
#               8080): {'start_time': 1741546074.930734, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.137',
#               '192.168.64.3',
#               37727,
#               8080): {'start_time': 1741546074.93179, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.104',
#               '192.168.64.3',
#               53483,
#               8080): {'start_time': 1741546074.932874, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.35',
#               '192.168.64.3',
#               29138,
#               8080): {'start_time': 1741546074.933954, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.101',
#               '192.168.64.3',
#               3454,
#               8080): {'start_time': 1741546074.934995, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.249',
#               '192.168.64.3',
#               22219,
#               8080): {'start_time': 1741546074.936092, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.87',
#               '192.168.64.3',
#               13053,
#               8080): {'start_time': 1741546074.937167, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.127',
#               '192.168.64.3',
#               50241,
#               8080): {'start_time': 1741546074.938269, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.4',
#               '192.168.64.3',
#               48677,
#               8080): {'start_time': 1741546074.939299, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.93',
#               '192.168.64.3',
#               28804,
#               8080): {'start_time': 1741546074.940387, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.114',
#               '192.168.64.3',
#               64573,
#               8080): {'start_time': 1741546074.941498, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.238',
#               '192.168.64.3',
#               22752,
#               8080): {'start_time': 1741546074.942544, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.6',
#               '192.168.64.3',
#               54417,
#               8080): {'start_time': 1741546074.943602, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.12',
#               '192.168.64.3',
#               39476,
#               8080): {'start_time': 1741546074.94472, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.68',
#               '192.168.64.3',
#               24534,
#               8080): {'start_time': 1741546074.945769, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.179',
#               '192.168.64.3',
#               28859,
#               8080): {'start_time': 1741546074.946825, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.173',
#               '192.168.64.3',
#               1840,
#               8080): {'start_time': 1741546074.947922, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.21',
#               '192.168.64.3',
#               6485,
#               8080): {'start_time': 1741546074.949025, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.27',
#               '192.168.64.3',
#               39136,
#               8080): {'start_time': 1741546074.950082, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.178',
#               '192.168.64.3',
#               10343,
#               8080): {'start_time': 1741546074.951176, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.13',
#               '192.168.64.3',
#               11523,
#               8080): {'start_time': 1741546074.952219, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.235',
#               '192.168.64.3',
#               40041,
#               8080): {'start_time': 1741546074.953328, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.129',
#               '192.168.64.3',
#               43397,
#               8080): {'start_time': 1741546074.954372, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.51',
#               '192.168.64.3',
#               27844,
#               8080): {'start_time': 1741546074.955457, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.233',
#               '192.168.64.3',
#               41024,
#               8080): {'start_time': 1741546074.956552, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.47',
#               '192.168.64.3',
#               49508,
#               8080): {'start_time': 1741546074.957609, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.12',
#               '192.168.64.3',
#               13251,
#               8080): {'start_time': 1741546074.958682, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.66',
#               '192.168.64.3',
#               15794,
#               8080): {'start_time': 1741546074.959735, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.162',
#               '192.168.64.3',
#               50561,
#               8080): {'start_time': 1741546074.960849, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.141',
#               '192.168.64.3',
#               26285,
#               8080): {'start_time': 1741546074.961906, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.145',
#               '192.168.64.3',
#               50118,
#               8080): {'start_time': 1741546074.963014, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.84',
#               '192.168.64.3',
#               49440,
#               8080): {'start_time': 1741546074.964064, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.53',
#               '192.168.64.3',
#               8011,
#               8080): {'start_time': 1741546074.965144, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.63',
#               '192.168.64.3',
#               37132,
#               8080): {'start_time': 1741546074.966242, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.238',
#               '192.168.64.3',
#               12117,
#               8080): {'start_time': 1741546074.967285, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.79',
#               '192.168.64.3',
#               3764,
#               8080): {'start_time': 1741546074.968383, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.194',
#               '192.168.64.3',
#               58675,
#               8080): {'start_time': 1741546074.969496, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.65',
#               '192.168.64.3',
#               46558,
#               8080): {'start_time': 1741546074.970563, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.110',
#               '192.168.64.3',
#               3756,
#               8080): {'start_time': 1741546074.971684, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.135',
#               '192.168.64.3',
#               35643,
#               8080): {'start_time': 1741546074.972746, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.255',
#               '192.168.64.3',
#               56847,
#               8080): {'start_time': 1741546074.973895, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.0',
#               '192.168.64.3',
#               33077,
#               8080): {'start_time': 1741546074.974908, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.31',
#               '192.168.64.3',
#               40943,
#               8080): {'start_time': 1741546074.976011, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.84',
#               '192.168.64.3',
#               14131,
#               8080): {'start_time': 1741546074.977194, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.167',
#               '192.168.64.3',
#               44169,
#               8080): {'start_time': 1741546074.978176, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.82',
#               '192.168.64.3',
#               33725,
#               8080): {'start_time': 1741546074.97924, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.96',
#               '192.168.64.3',
#               24962,
#               8080): {'start_time': 1741546074.980375, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.25',
#               '192.168.64.3',
#               53211,
#               8080): {'start_time': 1741546074.98146, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.129',
#               '192.168.64.3',
#               58972,
#               8080): {'start_time': 1741546074.982539, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.52',
#               '192.168.64.3',
#               37288,
#               8080): {'start_time': 1741546074.983581, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.218',
#               '192.168.64.3',
#               63844,
#               8080): {'start_time': 1741546074.984702, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.201',
#               '192.168.64.3',
#               52344,
#               8080): {'start_time': 1741546074.985764, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.177',
#               '192.168.64.3',
#               16053,
#               8080): {'start_time': 1741546074.986843, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.212',
#               '192.168.64.3',
#               49783,
#               8080): {'start_time': 1741546074.987863, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.174',
#               '192.168.64.3',
#               11950,
#               8080): {'start_time': 1741546074.988966, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.194',
#               '192.168.64.3',
#               2285,
#               8080): {'start_time': 1741546074.990044, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.17',
#               '192.168.64.3',
#               64583,
#               8080): {'start_time': 1741546074.991118, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.204',
#               '192.168.64.3',
#               10009,
#               8080): {'start_time': 1741546074.992232, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.189',
#               '192.168.64.3',
#               46544,
#               8080): {'start_time': 1741546074.993223, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.187',
#               '192.168.64.3',
#               2318,
#               8080): {'start_time': 1741546074.99433, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.211',
#               '192.168.64.3',
#               31144,
#               8080): {'start_time': 1741546074.99537, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.113',
#               '192.168.64.3',
#               40794,
#               8080): {'start_time': 1741546074.996477, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.174',
#               '192.168.64.3',
#               26566,
#               8080): {'start_time': 1741546074.997536, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.47',
#               '192.168.64.3',
#               22459,
#               8080): {'start_time': 1741546074.998609, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.199',
#               '192.168.64.3',
#               20873,
#               8080): {'start_time': 1741546074.999687, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.193',
#               '192.168.64.3',
#               19572,
#               8080): {'start_time': 1741546075.000765, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.88',
#               '192.168.64.3',
#               62602,
#               8080): {'start_time': 1741546075.001855, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.26',
#               '192.168.64.3',
#               44524,
#               8080): {'start_time': 1741546075.002927, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.62',
#               '192.168.64.3',
#               44222,
#               8080): {'start_time': 1741546075.003975, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.96',
#               '192.168.64.3',
#               49104,
#               8080): {'start_time': 1741546075.005072, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.200',
#               '192.168.64.3',
#               49248,
#               8080): {'start_time': 1741546075.006134, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.110',
#               '192.168.64.3',
#               61111,
#               8080): {'start_time': 1741546075.007252, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.169',
#               '192.168.64.3',
#               12802,
#               8080): {'start_time': 1741546075.00834, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.48',
#               '192.168.64.3',
#               36410,
#               8080): {'start_time': 1741546075.009402, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.244',
#               '192.168.64.3',
#               14948,
#               8080): {'start_time': 1741546075.010474, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.12',
#               '192.168.64.3',
#               14312,
#               8080): {'start_time': 1741546075.011544, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.185',
#               '192.168.64.3',
#               1484,
#               8080): {'start_time': 1741546075.012632, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.217',
#               '192.168.64.3',
#               38491,
#               8080): {'start_time': 1741546075.013688, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.237',
#               '192.168.64.3',
#               35240,
#               8080): {'start_time': 1741546075.014758, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.157',
#               '192.168.64.3',
#               41115,
#               8080): {'start_time': 1741546075.015831, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.160',
#               '192.168.64.3',
#               55526,
#               8080): {'start_time': 1741546075.016909, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.230',
#               '192.168.64.3',
#               54867,
#               8080): {'start_time': 1741546075.01798, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.242',
#               '192.168.64.3',
#               4351,
#               8080): {'start_time': 1741546075.019057, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.24',
#               '192.168.64.3',
#               57390,
#               8080): {'start_time': 1741546075.020123, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.51',
#               '192.168.64.3',
#               42123,
#               8080): {'start_time': 1741546075.021197, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.155',
#               '192.168.64.3',
#               58641,
#               8080): {'start_time': 1741546075.02222, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.142',
#               '192.168.64.3',
#               37328,
#               8080): {'start_time': 1741546075.023326, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.225',
#               '192.168.64.3',
#               44275,
#               8080): {'start_time': 1741546075.024347, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.90',
#               '192.168.64.3',
#               28450,
#               8080): {'start_time': 1741546075.025471, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.207',
#               '192.168.64.3',
#               22562,
#               8080): {'start_time': 1741546075.02655, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.206',
#               '192.168.64.3',
#               15827,
#               8080): {'start_time': 1741546075.027608, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.171',
#               '192.168.64.3',
#               59444,
#               8080): {'start_time': 1741546075.028688, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.154',
#               '192.168.64.3',
#               50006,
#               8080): {'start_time': 1741546075.02975, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.75',
#               '192.168.64.3',
#               2680,
#               8080): {'start_time': 1741546075.030835, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.56',
#               '192.168.64.3',
#               14085,
#               8080): {'start_time': 1741546075.031906, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.199',
#               '192.168.64.3',
#               45887,
#               8080): {'start_time': 1741546075.032931, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.246',
#               '192.168.64.3',
#               28415,
#               8080): {'start_time': 1741546075.034044, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.206',
#               '192.168.64.3',
#               2054,
#               8080): {'start_time': 1741546075.035116, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.185',
#               '192.168.64.3',
#               65458,
#               8080): {'start_time': 1741546075.036144, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.202',
#               '192.168.64.3',
#               4897,
#               8080): {'start_time': 1741546075.037228, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.182',
#               '192.168.64.3',
#               39048,
#               8080): {'start_time': 1741546075.03834, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.137',
#               '192.168.64.3',
#               33959,
#               8080): {'start_time': 1741546075.03941, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.83',
#               '192.168.64.3',
#               10959,
#               8080): {'start_time': 1741546075.040491, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.38',
#               '192.168.64.3',
#               54763,
#               8080): {'start_time': 1741546075.041553, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.29',
#               '192.168.64.3',
#               49641,
#               8080): {'start_time': 1741546075.042609, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.73',
#               '192.168.64.3',
#               36032,
#               8080): {'start_time': 1741546075.043727, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.47',
#               '192.168.64.3',
#               17292,
#               8080): {'start_time': 1741546075.044772, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.241',
#               '192.168.64.3',
#               53412,
#               8080): {'start_time': 1741546075.045854, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.69',
#               '192.168.64.3',
#               12911,
#               8080): {'start_time': 1741546075.04695, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.34',
#               '192.168.64.3',
#               47756,
#               8080): {'start_time': 1741546075.04803, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.108',
#               '192.168.64.3',
#               17278,
#               8080): {'start_time': 1741546075.049131, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.221',
#               '192.168.64.3',
#               17249,
#               8080): {'start_time': 1741546075.050216, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.219',
#               '192.168.64.3',
#               19722,
#               8080): {'start_time': 1741546075.05123, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.205',
#               '192.168.64.3',
#               32796,
#               8080): {'start_time': 1741546075.052298, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.230',
#               '192.168.64.3',
#               37135,
#               8080): {'start_time': 1741546075.053403, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.129',
#               '192.168.64.3',
#               24856,
#               8080): {'start_time': 1741546075.054467, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.72',
#               '192.168.64.3',
#               57979,
#               8080): {'start_time': 1741546075.055547, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.43',
#               '192.168.64.3',
#               48290,
#               8080): {'start_time': 1741546075.056589, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.172',
#               '192.168.64.3',
#               8633,
#               8080): {'start_time': 1741546075.057717, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.24',
#               '192.168.64.3',
#               40909,
#               8080): {'start_time': 1741546075.058754, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.137',
#               '192.168.64.3',
#               53096,
#               8080): {'start_time': 1741546075.059858, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.193',
#               '192.168.64.3',
#               37241,
#               8080): {'start_time': 1741546075.060928, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.30',
#               '192.168.64.3',
#               30570,
#               8080): {'start_time': 1741546075.061991, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.151',
#               '192.168.64.3',
#               22605,
#               8080): {'start_time': 1741546075.063065, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.217',
#               '192.168.64.3',
#               57307,
#               8080): {'start_time': 1741546075.064142, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.177',
#               '192.168.64.3',
#               3849,
#               8080): {'start_time': 1741546075.0652, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.44',
#               '192.168.64.3',
#               58159,
#               8080): {'start_time': 1741546075.066301, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.218',
#               '192.168.64.3',
#               34691,
#               8080): {'start_time': 1741546075.06738, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.134',
#               '192.168.64.3',
#               57184,
#               8080): {'start_time': 1741546075.068463, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.7',
#               '192.168.64.3',
#               65322,
#               8080): {'start_time': 1741546075.069535, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.104',
#               '192.168.64.3',
#               11563,
#               8080): {'start_time': 1741546075.070618, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.228',
#               '192.168.64.3',
#               52378,
#               8080): {'start_time': 1741546075.071687, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.8',
#               '192.168.64.3',
#               16692,
#               8080): {'start_time': 1741546075.072758, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.122',
#               '192.168.64.3',
#               19557,
#               8080): {'start_time': 1741546075.073859, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.172',
#               '192.168.64.3',
#               9676,
#               8080): {'start_time': 1741546075.074911, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.175',
#               '192.168.64.3',
#               32776,
#               8080): {'start_time': 1741546075.075988, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.26',
#               '192.168.64.3',
#               15391,
#               8080): {'start_time': 1741546075.077061, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.27',
#               '192.168.64.3',
#               55749,
#               8080): {'start_time': 1741546075.07816, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.37',
#               '192.168.64.3',
#               59513,
#               8080): {'start_time': 1741546075.079203, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.72',
#               '192.168.64.3',
#               23750,
#               8080): {'start_time': 1741546075.080234, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.65',
#               '192.168.64.3',
#               54800,
#               8080): {'start_time': 1741546075.081246, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.149',
#               '192.168.64.3',
#               51671,
#               8080): {'start_time': 1741546075.082336, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.128',
#               '192.168.64.3',
#               50849,
# ...
#               64112,
#               8080): {'start_time': 1741546075.766784, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.236',
#               '192.168.64.3',
#               31824,
#               8080): {'start_time': 1741546075.767844, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.58',
#               '192.168.64.3',
#               35246,
#               8080): {'start_time': 1741546075.768875, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.240',
#               '192.168.64.3',
#               7098,
#               8080): {'start_time': 1741546075.770171, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.237',
#               '192.168.64.3',
#               47320,
#               8080): {'start_time': 1741546075.771079, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.9',
#               '192.168.64.3',
#               11815,
#               8080): {'start_time': 1741546075.77215, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.196',
#               '192.168.64.3',
#               60478,
#               8080): {'start_time': 1741546075.773191, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.67',
#               '192.168.64.3',
#               58074,
#               8080): {'start_time': 1741546075.774245, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.113',
#               '192.168.64.3',
#               13789,
#               8080): {'start_time': 1741546075.775314, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.36',
#               '192.168.64.3',
#               24283,
#               8080): {'start_time': 1741546075.776351, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.65',
#               '192.168.64.3',
#               33800,
#               8080): {'start_time': 1741546075.777469, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.30',
#               '192.168.64.3',
#               56996,
#               8080): {'start_time': 1741546075.778535, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.56',
#               '192.168.64.3',
#               6124,
#               8080): {'start_time': 1741546075.779606, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.2',
#               '192.168.64.3',
#               57756,
#               8080): {'start_time': 1741546075.780634, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.214',
#               '192.168.64.3',
#               63328,
#               8080): {'start_time': 1741546075.781753, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.204',
#               '192.168.64.3',
#               40862,
#               8080): {'start_time': 1741546075.782825, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.143',
#               '192.168.64.3',
#               51898,
#               8080): {'start_time': 1741546075.783895, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.204',
#               '192.168.64.3',
#               49839,
#               8080): {'start_time': 1741546075.784991, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.66',
#               '192.168.64.3',
#               10853,
#               8080): {'start_time': 1741546075.78604, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.8',
#               '192.168.64.3',
#               4409,
#               8080): {'start_time': 1741546075.787143, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.202',
#               '192.168.64.3',
#               56654,
#               8080): {'start_time': 1741546075.788147, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.83',
#               '192.168.64.3',
#               60581,
#               8080): {'start_time': 1741546075.789225, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.162',
#               '192.168.64.3',
#               27414,
#               8080): {'start_time': 1741546075.790352, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.46',
#               '192.168.64.3',
#               13210,
#               8080): {'start_time': 1741546075.791398, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.112',
#               '192.168.64.3',
#               11568,
#               8080): {'start_time': 1741546075.792497, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.33',
#               '192.168.64.3',
#               32724,
#               8080): {'start_time': 1741546075.793598, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.47',
#               '192.168.64.3',
#               44303,
#               8080): {'start_time': 1741546075.794677, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.10',
#               '192.168.64.3',
#               31092,
#               8080): {'start_time': 1741546075.795767, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.252',
#               '192.168.64.3',
#               34863,
#               8080): {'start_time': 1741546075.796828, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.162',
#               '192.168.64.3',
#               45831,
#               8080): {'start_time': 1741546075.797919, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.82',
#               '192.168.64.3',
#               54544,
#               8080): {'start_time': 1741546075.798993, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.234',
#               '192.168.64.3',
#               4704,
#               8080): {'start_time': 1741546075.800074, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.166',
#               '192.168.64.3',
#               13368,
#               8080): {'start_time': 1741546075.801104, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.190',
#               '192.168.64.3',
#               35179,
#               8080): {'start_time': 1741546075.802219, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.188',
#               '192.168.64.3',
#               19007,
#               8080): {'start_time': 1741546075.803334, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.140',
#               '192.168.64.3',
#               5880,
#               8080): {'start_time': 1741546075.804402, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.248',
#               '192.168.64.3',
#               2969,
#               8080): {'start_time': 1741546075.805469, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.191',
#               '192.168.64.3',
#               43083,
#               8080): {'start_time': 1741546075.806526, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.42',
#               '192.168.64.3',
#               31694,
#               8080): {'start_time': 1741546075.807598, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.38',
#               '192.168.64.3',
#               23836,
#               8080): {'start_time': 1741546075.808683, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.129',
#               '192.168.64.3',
#               4854,
#               8080): {'start_time': 1741546075.80977, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.190',
#               '192.168.64.3',
#               15142,
#               8080): {'start_time': 1741546075.810839, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.4',
#               '192.168.64.3',
#               51856,
#               8080): {'start_time': 1741546075.811912, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.64',
#               '192.168.64.3',
#               11007,
#               8080): {'start_time': 1741546075.813005, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.99',
#               '192.168.64.3',
#               64016,
#               8080): {'start_time': 1741546075.814042, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.48',
#               '192.168.64.3',
#               29949,
#               8080): {'start_time': 1741546075.815137, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.234',
#               '192.168.64.3',
#               64669,
#               8080): {'start_time': 1741546075.816176, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.189',
#               '192.168.64.3',
#               45963,
#               8080): {'start_time': 1741546075.817282, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.103',
#               '192.168.64.3',
#               9241,
#               8080): {'start_time': 1741546075.818323, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.27',
#               '192.168.64.3',
#               44663,
#               8080): {'start_time': 1741546075.819411, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.9',
#               '192.168.64.3',
#               64243,
#               8080): {'start_time': 1741546075.820489, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.36',
#               '192.168.64.3',
#               14535,
#               8080): {'start_time': 1741546075.821553, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.195',
#               '192.168.64.3',
#               6678,
#               8080): {'start_time': 1741546075.822625, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.208',
#               '192.168.64.3',
#               11737,
#               8080): {'start_time': 1741546075.823698, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.150',
#               '192.168.64.3',
#               50192,
#               8080): {'start_time': 1741546075.82473, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.70',
#               '192.168.64.3',
#               30136,
#               8080): {'start_time': 1741546075.825835, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.79',
#               '192.168.64.3',
#               40898,
#               8080): {'start_time': 1741546075.826911, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.48',
#               '192.168.64.3',
#               52935,
#               8080): {'start_time': 1741546075.828007, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.49',
#               '192.168.64.3',
#               64765,
#               8080): {'start_time': 1741546075.829074, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.177',
#               '192.168.64.3',
#               14199,
#               8080): {'start_time': 1741546075.83013, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.38',
#               '192.168.64.3',
#               21545,
#               8080): {'start_time': 1741546075.831228, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.65',
#               '192.168.64.3',
#               4517,
#               8080): {'start_time': 1741546075.832213, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.59',
#               '192.168.64.3',
#               40971,
#               8080): {'start_time': 1741546075.833338, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.230',
#               '192.168.64.3',
#               16283,
#               8080): {'start_time': 1741546075.834382, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.197',
#               '192.168.64.3',
#               7105,
#               8080): {'start_time': 1741546075.835452, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.218',
#               '192.168.64.3',
#               7477,
#               8080): {'start_time': 1741546075.836513, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.81',
#               '192.168.64.3',
#               30850,
#               8080): {'start_time': 1741546075.837634, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.164',
#               '192.168.64.3',
#               20530,
#               8080): {'start_time': 1741546075.838708, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.220',
#               '192.168.64.3',
#               33855,
#               8080): {'start_time': 1741546075.839769, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.134',
#               '192.168.64.3',
#               55286,
#               8080): {'start_time': 1741546075.840804, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.244',
#               '192.168.64.3',
#               6554,
#               8080): {'start_time': 1741546075.841907, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.5',
#               '192.168.64.3',
#               54615,
#               8080): {'start_time': 1741546075.842984, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.169',
#               '192.168.64.3',
#               21784,
#               8080): {'start_time': 1741546075.844065, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.226',
#               '192.168.64.3',
#               41357,
#               8080): {'start_time': 1741546075.845178, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.85',
#               '192.168.64.3',
#               57223,
#               8080): {'start_time': 1741546075.846229, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.39',
#               '192.168.64.3',
#               4379,
#               8080): {'start_time': 1741546075.847255, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.8',
#               '192.168.64.3',
#               40361,
#               8080): {'start_time': 1741546075.848313, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.14',
#               '192.168.64.3',
#               8561,
#               8080): {'start_time': 1741546075.849401, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.31',
#               '192.168.64.3',
#               30647,
#               8080): {'start_time': 1741546075.850475, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.191',
#               '192.168.64.3',
#               42108,
#               8080): {'start_time': 1741546075.851518, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.3',
#               '192.168.64.3',
#               10110,
#               8080): {'start_time': 1741546075.852582, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.109',
#               '192.168.64.3',
#               13077,
#               8080): {'start_time': 1741546075.853674, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.19',
#               '192.168.64.3',
#               37438,
#               8080): {'start_time': 1741546075.854748, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.35',
#               '192.168.64.3',
#               12880,
#               8080): {'start_time': 1741546075.855819, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.207',
#               '192.168.64.3',
#               7965,
#               8080): {'start_time': 1741546075.856895, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.142',
#               '192.168.64.3',
#               49908,
#               8080): {'start_time': 1741546075.857975, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.232',
#               '192.168.64.3',
#               40541,
#               8080): {'start_time': 1741546075.859083, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.100',
#               '192.168.64.3',
#               51645,
#               8080): {'start_time': 1741546075.860198, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.255',
#               '192.168.64.3',
#               22338,
#               8080): {'start_time': 1741546075.861292, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.128',
#               '192.168.64.3',
#               56549,
#               8080): {'start_time': 1741546075.862237, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.188',
#               '192.168.64.3',
#               2426,
#               8080): {'start_time': 1741546075.863322, 'fin_ack_time': None, 'end_time': None},
#              ('10.0.0.29',
#               '192.168.64.3',
#               44047,
#               8080): {'start_time': 1741546075.864375, 'fin_ack_time': None, 'end_time': None},
#              ...})

# %%
cap = pyshark.FileCapture("flood.pcap", display_filter="tcp.port==8080")
cap
# Out:
# <FileCapture flood.pcap>

# %%
pkt = cap[0]
pkt
# Out:
# <TCP Packet>

# %%
print(pkt)
# Out:
# Packet (Length: 66)
# Layer ETH
# :	Destination: a2:df:a3:3a:7b:53
# 	.... ..1. .... .... .... .... = LG bit: Locally administered address (this is NOT the factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: b6:e1:34:73:6f:67
# 	.... ..1. .... .... .... .... = LG bit: Locally administered address (this is NOT the factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Stream index: 1
# Layer IP
# :	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x00 (DSCP: CS0, ECN: Not-ECT)
# 	0000 00.. = Differentiated Services Codepoint: Default (0)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 52
# 	Identification: 0x0000 (0)
# 	010. .... = Flags: 0x2, Don't fragment
# 	0... .... = Reserved bit: Not set
# 	.1.. .... = Don't fragment: Set
# 	..0. .... = More fragments: Not set
# 	...0 0000 0000 0000 = Fragment Offset: 0
# 	Time to Live: 64
# 	Protocol: TCP (6)
# 	Header Checksum: 0x396e [validation disabled]
# 	Header checksum status: Unverified
# 	Source Address: 192.168.64.3
# 	Destination Address: 192.168.64.2
# 	Stream index: 1
# Layer TCP
# :	Source Port: 8080
# 	Destination Port: 52062
# 	Stream index: 93121
# 	Conversation completeness: Complete, NO_DATA (23)
# 	..0. .... = RST: Absent
# 	...1 .... = FIN: Present
# 	.... 0... = Data: Absent
# 	.... .1.. = ACK: Present
# 	.... ..1. = SYN-ACK: Present
# 	.... ...1 = SYN: Present
# 	Completeness Flags: ·F·ASS
# 	TCP Segment Len: 0
# 	Sequence Number: 2    (relative sequence number)
# 	Sequence Number (raw): 3302435165
# 	Next Sequence Number: 2    (relative sequence number)
# 	Acknowledgment Number: 2    (relative ack number)
# 	Acknowledgment number (raw): 1481893519
# 	1000 .... = Header Length: 32 bytes (8)
# 	Flags: 0x010 (ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Accurate ECN: Not set
# 	.... 0... .... = Congestion Window Reduced: Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 0... = Push: Not set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: ·······A····
# 	Window: 510
# 	Calculated window size: 65280
# 	Window size scaling factor: 128
# 	Checksum: 0xa8e0 [unverified]
# 	Checksum Status: Unverified
# 	Urgent Pointer: 0
# 	Options: (12 bytes), No-Operation (NOP), No-Operation (NOP), Timestamps
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	TCP Option - Timestamps: TSval 3486302778, TSecr 3327941149
# 	Length: 10
# 	Timestamp value: 3486302778
# 	Timestamp echo reply: 3327941149
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.052286000 seconds
# 	Time since previous frame in this TCP stream: 0.006631000 seconds
# 	SEQ/ACK analysis
# 	This is an ACK to the segment in frame: 110340
# 	The RTT to ACK the segment was: 0.006631000 seconds
# 	iRTT: 0.002889000 seconds
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	Kind: Time Stamp Option (8)

# %%
def give_details(pkt):
    src_ip = pkt.ip.src
    dst_ip = pkt.ip.dst
    flags = pkt.tcp.flags
    src_port = int(pkt.tcp.srcport)
    dst_port = int(pkt.tcp.dstport)
    timestamp = float(pkt.sniff_timestamp)
    print(src_ip, dst_ip, src_port, dst_port, flags, timestamp)

# %%
give_details(cap[0])
give_details(cap[1])
give_details(cap[2])
give_details(cap[3])
give_details(cap[4])
give_details(cap[5])
give_details(cap[6])
give_details(cap[7])
# Out:
# 192.168.64.2 192.168.64.3 46428 8080 0x0002 1741546054.376098
# 192.168.64.3 192.168.64.2 8080 46428 0x0012 1741546054.376651
# 192.168.64.2 192.168.64.3 46428 8080 0x0010 1741546054.377008
# 192.168.64.3 192.168.64.2 8080 46428 0x0011 1741546054.377894
# 192.168.64.2 192.168.64.3 46428 8080 0x0010 1741546054.379221
# 192.168.64.2 192.168.64.3 46428 8080 0x0011 1741546055.377783
# 192.168.64.3 192.168.64.2 8080 46428 0x0010 1741546055.38094
# 192.168.64.2 192.168.64.3 46438 8080 0x0002 1741546055.880526
